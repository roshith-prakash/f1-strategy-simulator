# %%
import fastf1
import pandas as pd
import numpy as np
import os

# -------------------------------------------------
# 1️⃣ Enable Cache (create if not exists)
# -------------------------------------------------
if not os.path.exists("cache"):
    os.mkdir("cache")

fastf1.Cache.enable_cache("cache")

# -------------------------------------------------
# 2️⃣ Load Session (Round 1 = Bahrain 2023)
# -------------------------------------------------
session = fastf1.get_session(2023, 1, "R")  # 1 = Bahrain GP
session.load()  # Load full session data

print("Session loaded successfully!")

# -------------------------------------------------
# 3️⃣ Extract Lap Data
# -------------------------------------------------
laps = session.laps

laps = session.laps

# Show first few records
print("\nFirst 5 rows:")
print(laps.head())

# Show all available columns
print("\nAvailable Columns:")
print(laps.columns)

# Optional: More detailed info (data types, null counts)
print("\nDataFrame Info:")
print(laps.info())

# if laps is None or laps.empty:
#     raise Exception("Laps data not loaded properly.")

# print("Total laps loaded:", len(laps))

# # -------------------------------------------------
# # 4️⃣ Select Required Columns
# # -------------------------------------------------
# dataset = laps[[
#     "Driver",
#     "LapNumber",
#     "LapTime",
#     "Compound",
#     "Stint"
# ]].copy()

# # -------------------------------------------------
# # 5️⃣ Clean Dataset
# # -------------------------------------------------
# dataset = dataset.dropna()

# # Convert LapTime to seconds
# dataset["LapTime"] = dataset["LapTime"].dt.total_seconds()

# # Remove unrealistic lap times (pit laps, safety car etc.)
# dataset = dataset[(dataset["LapTime"] > 60) & (dataset["LapTime"] < 200)]

# dataset.reset_index(drop=True, inplace=True)

# print("\nCleaned Dataset Preview:")
# print(dataset.head())
print("\nFinal number of laps:", len(dataset))
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.8.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '14', '55', '44', '18', '63', '77', '10', '23', '22', '2', '20', '21', '27', '24', '4', '31', '16', '81']
# Session loaded successfully!
#
# ...
